# %% [markdown]
# <a href="https://colab.research.google.com/github/bhanu080/bhanu080/blob/main/Practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import datetime

# %% [markdown]
# DataFrame

# %%
students=['Alice','Bob','Emily','Charlie']

# %%
scores=[90,80,65,50]

# %%
exam_results=pd.DataFrame(
    {
        "Name":students,
        "scores":scores
    }
)

# %%
exam_results
# Out:
#       Name  scores
# 0    Alice      90
# 1      Bob      80
# 2    Emily      65
# 3  Charlie      50

# %%
exam_results.loc[0,'scores']
# Out:
# 90

# %%
exam_results.loc[:,'scores']
# Out:
# 0    90
# 1    80
# 2    65
# 3    50
# Name: scores, dtype: int64

# %%
exam_results.loc[2,:]
# Out:
# Name      Emily
# scores       65
# Name: 2, dtype: object

# %%
exam_results["scores"]
# Out:
# 0    90
# 1    80
# 2    65
# 3    50
# Name: scores, dtype: int64

# %% [markdown]
# Add Columns

# %%
gender=['female','male','female','male']

# %%
exam_results['gender']=gender

# %%
exam_results
# Out:
#       Name  scores  gender
# 0    Alice      90  female
# 1      Bob      80    male
# 2    Emily      65  female
# 3  Charlie      50    male

# %%
exam_results['gender']
# Out:
# 0    female
# 1      male
# 2    female
# 3      male
# Name: gender, dtype: object

# %% [markdown]
# Remove Columns

# %%
exam_results.drop('Name',axis=1)
# Out:
#    scores  gender
# 0      90  female
# 1      80    male
# 2      65  female
# 3      50    male

# %%
exam_results
# Out:
#       Name  scores  gender
# 0    Alice      90  female
# 1      Bob      80    male
# 2    Emily      65  female
# 3  Charlie      50    male

# %% [markdown]
# Column names and Row Indexes

# %%
exam_results.columns
# Out:
# Index(['Name', 'scores', 'gender'], dtype='object')

# %%
exam_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   scores  4 non-null      int64
#  2   gender  4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
exam_results.describe()
# Out:
#        scores
# count    4.00
# mean    71.25
# std     17.50
# min     50.00
# 25%     61.25
# 50%     72.50
# 75%     82.50
# max     90.00

# %%
exam_results.rename({'Name':'FirstName'},axis=1)
# Out:
#   FirstName  scores  gender
# 0     Alice      90  female
# 1       Bob      80    male
# 2     Emily      65  female
# 3   Charlie      50    male

# %% [markdown]
# Dealing with Missing Values

# %%
sparse=pd.DataFrame(
    {
    'a':[1,2,3],
    'b':[np.nan,4,np.nan],
    'c':[5,np.nan,np.nan]
    }
)

# %%
sparse
# Out:
#    a    b    c
# 0  1  NaN  5.0
# 1  2  4.0  NaN
# 2  3  NaN  NaN

# %%
sparse.isna()
# Out:
#        a      b      c
# 0  False   True  False
# 1  False  False   True
# 2  False   True   True

# %%
sparse.fillna(0)
# Out:
#    a    b    c
# 0  1  0.0  5.0
# 1  2  4.0  0.0
# 2  3  0.0  0.0

# %%
sparse
# Out:
#    a    b    c
# 0  1  NaN  5.0
# 1  2  4.0  NaN
# 2  3  NaN  NaN

# %%
sparse.dropna(axis=1)
# Out:
#    a
# 0  1
# 1  2
# 2  3

# %% [markdown]
# Group by

# %%
exam_results.groupby('gender').mean()
# Out:
#         scores
# gender
# female    77.5
# male      65.0

# %%
exam_results
# Out:
#       Name  scores  gender
# 0    Alice      90  female
# 1      Bob      80    male
# 2    Emily      65  female
# 3  Charlie      50    male

# %%
mylist=[1,2,1,2]
exam_results.groupby(mylist).get_group(1)
# Out:
#     Name  scores  gender
# 0  Alice      90  female
# 2  Emily      65  female

# %%
exam_results.groupby(mylist).get_group(2)
# Out:
#       Name  scores gender
# 1      Bob      80   male
# 3  Charlie      50   male

# %% [markdown]
# Group the people who obtained marks above or below 70

# %%
above_70=exam_results['scores']>70
above_70
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: scores, dtype: bool

# %%
exam_results
# Out:
#       Name  scores  gender
# 0    Alice      90  female
# 1      Bob      80    male
# 2    Emily      65  female
# 3  Charlie      50    male

# %%
#the mean scores of students who scored above or below 70

# %%
exam_results.groupby(above_70).mean()
# Out:
#         scores
# scores
# False     57.5
# True      85.0

# %%
below_70=exam_results['scores']<70
below_70
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: scores, dtype: bool

# %%
exam_results
# Out:
#       Name  scores  gender
# 0    Alice      90  female
# 1      Bob      80    male
# 2    Emily      65  female
# 3  Charlie      50    male

# %%
# the mean scores of the students who scored above or below 70
exam_results.groupby(below_70).mean()
# Out:
#         scores
# scores
# False     85.0
# True      57.5

# %% [markdown]
# merginig and joining

# %%
contacts=pd.DataFrame(
    {
        'Name':['Alice','Charlie'],
        'Tel':['+91 999 999 99 99','+91 888 888 99 99']
    }
)

# %%
contacts
# Out:
#       Name                Tel
# 0    Alice  +91 999 999 99 99
# 1  Charlie  +91 888 888 99 99

# %%
exam_results.merge(contacts, left_on='Name', right_on='Name')  # defaults to inner join
# Out:
#       Name  scores  gender                Tel
# 0    Alice      90  female  +91 999 999 99 99
# 1  Charlie      50    male  +91 888 888 99 99

# %%
exam_results.merge(contacts, left_on='Name', right_on ='Name', how ='outer')
# Out:
#       Name  scores  gender                Tel
# 0    Alice      90  female  +91 999 999 99 99
# 1      Bob      80    male                NaN
# 2    Emily      65  female                NaN
# 3  Charlie      50    male  +91 888 888 99 99
